# %% [markdown]
# # PySpark interview exercises
#
# Run the cells from top to bottom.

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("MySparkApp")
    .master("local[*]")
    .getOrCreate()
)

# %% [markdown]
# ## Sample events

# %%
df = spark.createDataFrame(
    [
        {
            "event_id": 1,
            "user_id": 10,
            "event_type": "booking",
            "event_timestamp": "2026-01-01 10:00:00",
            "domain": "example.com",
            "country": "ES",
        },
        {
            "event_id": 2,
            "user_id": 11,
            "event_type": "click",
            "event_timestamp": "2026-01-01 11:00:00",
            "domain": "example.com",
            "country": "UK",
        },
    ]
)

df.show()

# %% [markdown]
# ## Exercise solutions
#
# Add a Markdown heading and a code cell for each solution.

# %%
# Exercise 1

# %% [markdown]
# ## Cleanup
#
# Run this after finishing the exercises.

# %%
spark.stop()
